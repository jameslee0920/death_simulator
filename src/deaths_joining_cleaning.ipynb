# %% [markdown]
# # CDC Mortality Data
#
# All data was pulled via [CDC Wonder](https://wonder.cdc.gov/controller/datarequest/D140;jsessionid=6168107B9517D078CF8CB7403852F177) and information about the data can be found [in this link](https://www.cdc.gov/nchs/data_access/cmf.htm).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Because CDC Wonder limits result size, several exports subset by state were required. The first 5 files contain 9 states worth of data and 6th has 6 (total of 51 including District of Columbia).

# %%
deaths01 = pd.read_csv("../data_raw/deaths_state_age_gender_race_cause_of_death_01.txt", sep = "\t")
deaths02 = pd.read_csv("../data_raw/deaths_state_age_gender_race_cause_of_death_02.txt", sep = "\t")
deaths03 = pd.read_csv("../data_raw/deaths_state_age_gender_race_cause_of_death_03.txt", sep = "\t")
deaths04 = pd.read_csv("../data_raw/deaths_state_age_gender_race_cause_of_death_04.txt", sep = "\t")
deaths05 = pd.read_csv("../data_raw/deaths_state_age_gender_race_cause_of_death_05.txt", sep = "\t")
deaths06 = pd.read_csv("../data_raw/deaths_state_age_gender_race_cause_of_death_06.txt", sep = "\t")

# %% [markdown]
# At the bottom of each text file, there are lines of extraneous text which needs to be removed, but it's not consistent for each file so manual checks are necessary:

# %%
deaths01.tail(50)
# Out:
#                                                   Notes                 State  \
# 6816                                                NaN  District of Columbia
# 6817                                                NaN  District of Columbia
# 6818                                                NaN  District of Columbia
# 6819                                                NaN  District of Columbia
# 6820                                                ---                   NaN
# 6821           Dataset: Compressed Mortality, 1999-2016                   NaN
# 6822                                  Query Parameters:                   NaN
# 6823  Title: deaths_state_age_gender_race_cause_of_d...                   NaN
# 6824  States: Alabama (01); Alaska (02); Arizona (04...                   NaN
# 6825                          District of Columbia (11)                   NaN
# 6826                                         Year: 2016                   NaN
# 6827  Group By: State; Age Group; Gender; Race; Caus...                   NaN
# 6828                              Show Totals: Disabled                   NaN
# 6829                         Show Zero Values: Disabled                   NaN
# 6830                             Show Suppressed: False                   NaN
# 6831                       Calculate Rates Per: 100,000                   NaN
# 6832                                                ---                   NaN
# 6833  Help: See http://wonder.cdc.gov/wonder/help/cm...                   NaN
# 6834                                                ---                   NaN
# 6835               Query Date: May 11, 2020 11:02:27 PM                   NaN
# 6836                                                ---                   NaN
# 6837  Suggested Citation: Centers for Disease Contro...                   NaN
# 6838  1999-2016 on CDC WONDER Online Database, relea...                   NaN
# 6839  2U, 2016, as compiled from data provided by th...                   NaN
# 6840  Program. Accessed at http://wonder.cdc.gov/cmf...                   NaN
# 6841                                                ---                   NaN
# 6842                                          Messages:                   NaN
# 6843  1. The full results are too long to be display...                   NaN
# 6844                                  not be available.                   NaN
# 6845                                                ---                   NaN
# 6846                                           Caveats:                   NaN
# 6847  1. Death rates are flagged as Unreliable when ...                   NaN
# 6848  http://wonder.cdc.gov/wonder/help/cmf.html#Unr...                   NaN
# 6849  2. About sub-national population figures for r...                   NaN
# 6850  1990-1999 series of bridged-race intercensal e...                   NaN
# 6851  are bridged-race April 1 census counts; popula...                   NaN
# 6852  intercensal estimates of the July 1 resident p...                   NaN
# 6853  estimates of the July 1 resident population, f...                   NaN
# 6854  3. The population figures used in the calculat...                   NaN
# 6855  resident population that is under one year of ...                   NaN
# 6856  4. Deaths of persons with Age "Not Stated" are...                   NaN
# 6857  so are not included in age-specific counts, ag...                   NaN
# 6858  http://wonder.cdc.gov/wonder/help/cmf.html#Not...                   NaN
# 6859  5. Information included on the death certifica...                   NaN
# 6860  funeral director as provided by an informant, ...                   NaN
# 6861  of observation. Race and ethnicity information...                   NaN
# 6862  are inconsistent between these two data source...                   NaN
# 6863  http://wonder.cdc.gov/wonder/help/cmf.html#Rac...                   NaN
# 6864  6. Changes to cause of death classification af...                   NaN
# 6865  http://wonder.cdc.gov/wonder/help/cmf.html#ICD...                   NaN
#
#       State Code  Age Group Age Group Code Gender Gender Code  \
# 6816        11.0  85+ years            85+   Male           M
# 6817        11.0  85+ years            85+   Male           M
# 6818        11.0  85+ years            85+   Male           M
# 6819        11.0  85+ years            85+   Male           M
# 6820         NaN        NaN            NaN    NaN         NaN
# 6821         NaN        NaN            NaN    NaN         NaN
# 6822         NaN        NaN            NaN    NaN         NaN
# 6823         NaN        NaN            NaN    NaN         NaN
# 6824         NaN        NaN            NaN    NaN         NaN
# 6825         NaN        NaN            NaN    NaN         NaN
# 6826         NaN        NaN            NaN    NaN         NaN
# 6827         NaN        NaN            NaN    NaN         NaN
# 6828         NaN        NaN            NaN    NaN         NaN
# 6829         NaN        NaN            NaN    NaN         NaN
# 6830         NaN        NaN            NaN    NaN         NaN
# 6831         NaN        NaN            NaN    NaN         NaN
# 6832         NaN        NaN            NaN    NaN         NaN
# 6833         NaN        NaN            NaN    NaN         NaN
# 6834         NaN        NaN            NaN    NaN         NaN
# 6835         NaN        NaN            NaN    NaN         NaN
# 6836         NaN        NaN            NaN    NaN         NaN
# 6837         NaN        NaN            NaN    NaN         NaN
# 6838         NaN        NaN            NaN    NaN         NaN
# 6839         NaN        NaN            NaN    NaN         NaN
# 6840         NaN        NaN            NaN    NaN         NaN
# 6841         NaN        NaN            NaN    NaN         NaN
# 6842         NaN        NaN            NaN    NaN         NaN
# 6843         NaN        NaN            NaN    NaN         NaN
# 6844         NaN        NaN            NaN    NaN         NaN
# 6845         NaN        NaN            NaN    NaN         NaN
# 6846         NaN        NaN            NaN    NaN         NaN
# 6847         NaN        NaN            NaN    NaN         NaN
# 6848         NaN        NaN            NaN    NaN         NaN
# 6849         NaN        NaN            NaN    NaN         NaN
# 6850         NaN        NaN            NaN    NaN         NaN
# 6851         NaN        NaN            NaN    NaN         NaN
# 6852         NaN        NaN            NaN    NaN         NaN
# 6853         NaN        NaN            NaN    NaN         NaN
# 6854         NaN        NaN            NaN    NaN         NaN
# 6855         NaN        NaN            NaN    NaN         NaN
# 6856         NaN        NaN            NaN    NaN         NaN
# 6857         NaN        NaN            NaN    NaN         NaN
# 6858         NaN        NaN            NaN    NaN         NaN
# 6859         NaN        NaN            NaN    NaN         NaN
# 6860         NaN        NaN            NaN    NaN         NaN
# 6861         NaN        NaN            NaN    NaN         NaN
# 6862         NaN        NaN            NaN    NaN         NaN
# 6863         NaN        NaN            NaN    NaN         NaN
# 6864         NaN        NaN            NaN    NaN         NaN
# 6865         NaN        NaN            NaN    NaN         NaN
#
#                            Race Race Code  \
# 6816  Black or African American    2054-5
# 6817  Black or African American    2054-5
# 6818                      White    2106-3
# 6819                      White    2106-3
# 6820                        NaN       NaN
# 6821                        NaN       NaN
# 6822                        NaN       NaN
# 6823                        NaN       NaN
# 6824                        NaN       NaN
# 6825                        NaN       NaN
# 6826                        NaN       NaN
# 6827                        NaN       NaN
# 6828                        NaN       NaN
# 6829                        NaN       NaN
# 6830                        NaN       NaN
# 6831                        NaN       NaN
# 6832                        NaN       NaN
# 6833                        NaN       NaN
# 6834                        NaN       NaN
# 6835                        NaN       NaN
# 6836                        NaN       NaN
# 6837                        NaN       NaN
# 6838                        NaN       NaN
# 6839                        NaN       NaN
# 6840                        NaN       NaN
# 6841                        NaN       NaN
# 6842                        NaN       NaN
# 6843                        NaN       NaN
# 6844                        NaN       NaN
# 6845                        NaN       NaN
# 6846                        NaN       NaN
# 6847                        NaN       NaN
# 6848                        NaN       NaN
# 6849                        NaN       NaN
# 6850                        NaN       NaN
# 6851                        NaN       NaN
# 6852                        NaN       NaN
# 6853                        NaN       NaN
# 6854                        NaN       NaN
# 6855                        NaN       NaN
# 6856                        NaN       NaN
# 6857                        NaN       NaN
# 6858                        NaN       NaN
# 6859                        NaN       NaN
# 6860                        NaN       NaN
# 6861                        NaN       NaN
# 6862                        NaN       NaN
# 6863                        NaN       NaN
# 6864                        NaN       NaN
# 6865                        NaN       NaN
#
#                                          Cause of death Cause of death Code  \
# 6816                      Atherosclerotic heart disease               I25.1
# 6817  Stroke, not specified as haemorrhage or infarc...                 I64
# 6818                     Alzheimer disease, unspecified               G30.9
# 6819  Atherosclerotic cardiovascular disease, so des...               I25.0
# 6820                                                NaN                 NaN
# 6821                                                NaN                 NaN
# 6822                                                NaN                 NaN
# 6823                                                NaN                 NaN
# 6824                                                NaN                 NaN
# 6825                                                NaN                 NaN
# 6826                                                NaN                 NaN
# 6827                                                NaN                 NaN
# 6828                                                NaN                 NaN
# 6829                                                NaN                 NaN
# 6830                                                NaN                 NaN
# 6831                                                NaN                 NaN
# 6832                                                NaN                 NaN
# 6833                                                NaN                 NaN
# 6834                                                NaN                 NaN
# 6835                                                NaN                 NaN
# 6836                                                NaN                 NaN
# 6837                                                NaN                 NaN
# 6838                                                NaN                 NaN
# 6839                                                NaN                 NaN
# 6840                                                NaN                 NaN
# 6841                                                NaN                 NaN
# 6842                                                NaN                 NaN
# 6843                                                NaN                 NaN
# 6844                                                NaN                 NaN
# 6845                                                NaN                 NaN
# 6846                                                NaN                 NaN
# 6847                                                NaN                 NaN
# 6848                                                NaN                 NaN
# 6849                                                NaN                 NaN
# 6850                                                NaN                 NaN
# 6851                                                NaN                 NaN
# 6852                                                NaN                 NaN
# 6853                                                NaN                 NaN
# 6854                                                NaN                 NaN
# 6855                                                NaN                 NaN
# 6856                                                NaN                 NaN
# 6857                                                NaN                 NaN
# 6858                                                NaN                 NaN
# 6859                                                NaN                 NaN
# 6860                                                NaN                 NaN
# 6861                                                NaN                 NaN
# 6862                                                NaN                 NaN
# 6863                                                NaN                 NaN
# 6864                                                NaN                 NaN
# 6865                                                NaN                 NaN
#
#       Deaths  Population          Crude Rate
# 6816    19.0      1998.0  951.0 (Unreliable)
# 6817    11.0      1998.0  550.6 (Unreliable)
# 6818    10.0      1474.0  678.4 (Unreliable)
# 6819    22.0      1474.0              1492.5
# 6820     NaN         NaN                 NaN
# 6821     NaN         NaN                 NaN
# 6822     NaN         NaN                 NaN
# 6823     NaN         NaN                 NaN
# 6824     NaN         NaN                 NaN
# 6825     NaN         NaN                 NaN
# 6826     NaN         NaN                 NaN
# 6827     NaN         NaN                 NaN
# 6828     NaN         NaN                 NaN
# 6829     NaN         NaN                 NaN
# 6830     NaN         NaN                 NaN
# 6831     NaN         NaN                 NaN
# 6832     NaN         NaN                 NaN
# 6833     NaN         NaN                 NaN
# 6834     NaN         NaN                 NaN
# 6835     NaN         NaN                 NaN
# 6836     NaN         NaN                 NaN
# 6837     NaN         NaN                 NaN
# 6838     NaN         NaN                 NaN
# 6839     NaN         NaN                 NaN
# 6840     NaN         NaN                 NaN
# 6841     NaN         NaN                 NaN
# 6842     NaN         NaN                 NaN
# 6843     NaN         NaN                 NaN
# 6844     NaN         NaN                 NaN
# 6845     NaN         NaN                 NaN
# 6846     NaN         NaN                 NaN
# 6847     NaN         NaN                 NaN
# 6848     NaN         NaN                 NaN
# 6849     NaN         NaN                 NaN
# 6850     NaN         NaN                 NaN
# 6851     NaN         NaN                 NaN
# 6852     NaN         NaN                 NaN
# 6853     NaN         NaN                 NaN
# 6854     NaN         NaN                 NaN
# 6855     NaN         NaN                 NaN
# 6856     NaN         NaN                 NaN
# 6857     NaN         NaN                 NaN
# 6858     NaN         NaN                 NaN
# 6859     NaN         NaN                 NaN
# 6860     NaN         NaN                 NaN
# 6861     NaN         NaN                 NaN
# 6862     NaN         NaN                 NaN
# 6863     NaN         NaN                 NaN
# 6864     NaN         NaN                 NaN
# 6865     NaN         NaN                 NaN

# %% [markdown]
# As can be seen, there are many rows of non-data at the end of the text document that need to be removed. The number of rows is inconsistent between files so each was investigated for its cutoff:

# %%
deaths01 = deaths01[:6820]

# %%
deaths01.tail()
# Out:
#      Notes                 State  State Code  Age Group Age Group Code Gender  \
# 6815   NaN  District of Columbia        11.0  85+ years            85+   Male
# 6816   NaN  District of Columbia        11.0  85+ years            85+   Male
# 6817   NaN  District of Columbia        11.0  85+ years            85+   Male
# 6818   NaN  District of Columbia        11.0  85+ years            85+   Male
# 6819   NaN  District of Columbia        11.0  85+ years            85+   Male
#
#      Gender Code                       Race Race Code  \
# 6815           M  Black or African American    2054-5
# 6816           M  Black or African American    2054-5
# 6817           M  Black or African American    2054-5
# 6818           M                      White    2106-3
# 6819           M                      White    2106-3
#
#                                          Cause of death Cause of death Code  \
# 6815  Atherosclerotic cardiovascular disease, so des...               I25.0
# 6816                      Atherosclerotic heart disease               I25.1
# 6817  Stroke, not specified as haemorrhage or infarc...                 I64
# 6818                     Alzheimer disease, unspecified               G30.9
# 6819  Atherosclerotic cardiovascular disease, so des...               I25.0
#
#       Deaths  Population          Crude Rate
# 6815    26.0      1998.0              1301.3
# 6816    19.0      1998.0  951.0 (Unreliable)
# 6817    11.0      1998.0  550.6 (Unreliable)
# 6818    10.0      1474.0  678.4 (Unreliable)
# 6819    22.0      1474.0              1492.5

# %% [markdown]
# Above, the last row is now the final row of data.
#
# For the other datasets, the unecessary rows will simply be removed without illustration:

# %%
deaths02 = deaths02[:8239]
deaths03 = deaths02[:6445]
deaths04 = deaths04[:7307]
deaths05 = deaths05[:7819]
deaths06 = deaths06[:3337]

# %% [markdown]
# Now that the data is uniform, the datasets can be bound together:

# %%
deaths = pd.concat([deaths01, deaths02, deaths03, deaths04, deaths05, deaths06])

# %% [markdown]
# With the data concatenated, the contents now need to be explored:

# %%
deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39967 entries, 0 to 3336
# Data columns (total 14 columns):
# Notes                  0 non-null object
# State                  39967 non-null object
# State Code             39967 non-null float64
# Age Group              39967 non-null object
# Age Group Code         39967 non-null object
# Gender                 39967 non-null object
# Gender Code            39967 non-null object
# Race                   39967 non-null object
# Race Code              39967 non-null object
# Cause of death         39967 non-null object
# Cause of death Code    39967 non-null object
# Deaths                 39967 non-null float64
# Population             39967 non-null float64
# Crude Rate             39967 non-null object
# dtypes: float64(3), object(11)
# memory usage: 4.6+ MB

# %% [markdown]
# Looks like Crude Rate may need to be numeric, but let's see what kinds of values are in each non-numeric column:

# %%
for c in deaths[['Notes', 'State', 'Age Group', 'Age Group Code', 'Gender', 'Gender Code', 'Race', 'Race Code',
                'Cause of death','Cause of death Code', 'Crude Rate']].columns:
    print("---- %s ---" % c)
    print(deaths[c].value_counts())
# Out:
# ---- Notes ---
# Series([], Name: Notes, dtype: int64)
# ---- State ---
# Florida                 4390
# Illinois                2978
# California              2964
# Georgia                 2708
# Texas                   2347
# Indiana                 1940
# New York                1858
# Pennsylvania            1612
# Ohio                    1544
# North Carolina          1391
# Virginia                1132
# New Jersey              1122
# Tennessee               1065
# Alabama                  989
# South Carolina           920
# Arizona                  833
# Washington               831
# Kentucky                 818
# Wisconsin                775
# Colorado                 658
# Oklahoma                 652
# Oregon                   572
# Arkansas                 562
# Connecticut              513
# Idaho                    496
# Iowa                     461
# Kansas                   459
# Hawaii                   434
# West Virginia            421
# Nevada                   418
# New Mexico               350
# Utah                     346
# Nebraska                 292
# New Hampshire            226
# Rhode Island             175
# Delaware                 168
# South Dakota             130
# North Dakota             106
# Vermont                  103
# District of Columbia      85
# Wyoming                   75
# Alaska                    48
# Name: State, dtype: int64
# ---- Age Group ---
# 85+ years      9500
# 75-84 years    9179
# 65-74 years    8366
# 55-64 years    6636
# 45-54 years    3415
# 35-44 years    1292
# 25-34 years     727
# < 1 year        352
# 20-24 years     332
# 15-19 years     162
# 1-4 years         5
# 10-14 years       1
# Name: Age Group, dtype: int64
# ---- Age Group Code ---
# 85+      9500
# 75-84    9179
# 65-74    8366
# 55-64    6636
# 45-54    3415
# 35-44    1292
# 25-34     727
# 1         352
# 20-24     332
# 15-19     162
# 1-4         5
# 10-14       1
# Name: Age Group Code, dtype: int64
# ---- Gender ---
# Male      21199
# Female    18768
# Name: Gender, dtype: int64
# ---- Gender Code ---
# M    21199
# F    18768
# Name: Gender Code, dtype: int64
# ---- Race ---
# White                               32037
# Black or African American            6631
# Asian or Pacific Islander            1186
# American Indian or Alaska Native      113
# Name: Race, dtype: int64
# ---- Race Code ---
# 2106-3    32037
# 2054-5     6631
# A-PI       1186
# 1002-5      113
# Name: Race Code, dtype: int64
# ---- Cause of death ---
# Bronchus or lung, unspecified - Malignant neoplasms                                                                         835
# Atherosclerotic heart disease                                                                                               811
# Acute myocardial infarction, unspecified                                                                                    787
# Atherosclerotic cardiovascular disease, so described                                                                        696
# Chronic obstructive pulmonary disease, unspecified                                                                          639
# Colon, unspecified - Malignant neoplasms                                                                                    617
# Stroke, not specified as haemorrhage or infarction                                                                          602
# Pancreas, unspecified - Malignant neoplasms                                                                                 602
# Septicaemia, unspecified                                                                                                    584
# Unspecified diabetes mellitus, without complications                                                                        560
# Hypertensive heart disease without (congestive) heart failure                                                               555
# Pneumonia, unspecified                                                                                                      543
# Congestive heart failure                                                                                                    530
# Malignant neoplasm without specification of site                                                                            511
# Alzheimer disease, unspecified                                                                                              483
# Chronic kidney disease, stage 5                                                                                             481
# Unspecified dementia                                                                                                        473
# Essential (primary) hypertension                                                                                            455
# Accidental poisoning by and exposure to narcotics and psychodysleptics [hallucinogens], not elsewhere classified            448
# Breast, unspecified - Malignant neoplasms                                                                                   441
# Accidental poisoning by and exposure to other and unspecified drugs, medicaments and biological substances                  423
# Unspecified diabetes mellitus, with renal complications                                                                     407
# Cardiomyopathy, unspecified                                                                                                 402
# Person injured in unspecified motor-vehicle accident, traffic                                                               396
# Pneumonitis due to food and vomit                                                                                           375
# Other and unspecified cirrhosis of liver                                                                                    359
# Brain, unspecified - Malignant neoplasms                                                                                    357
# Intracerebral haemorrhage, unspecified                                                                                      349
# Non-insulin-dependent diabetes mellitus, without complications                                                              344
# Cardiac arrest, unspecified                                                                                                 344
#                                                                                                                            ...
# Staphylococcal infection, unspecified                                                                                         1
# Car occupant injured in collision with fixed or stationary object, passenger injured in traffic accident                      1
# Pedal cyclist injured in collision with car, pick-up truck or van, unspecified pedal cyclist injured in traffic accident      1
# Aortic aneurysm of unspecified site, without mention of rupture                                                               1
# Unspecified pulmonary haemorrhage originating in the perinatal period                                                         1
# Car occupant injured in noncollision transport accident, driver injured in traffic accident                                   1
# Influenza with pneumonia, virus not identified                                                                                1
# Coalworker pneumoconiosis                                                                                                     1
# Disease of intestine, unspecified                                                                                             1
# Ventricular tachycardia                                                                                                       1
# Hypo-osmolality and hyponatraemia                                                                                             1
# Mitral stenosis                                                                                                               1
# Penis, unspecified - Malignant neoplasms                                                                                      1
# Asphyxia                                                                                                                      1
# Connective and soft tissue of abdomen - Malignant neoplasms                                                                   1
# Agranulocytosis                                                                                                               1
# Fall involving chair                                                                                                          1
# Abnormal weight loss                                                                                                          1
# Death from direct obstetric cause occurring more than 42 days but less than one year after delivery                           1
# Bronchitis, not specified as acute or chronic                                                                                 1
# Disorder of brain, unspecified                                                                                                1
# Follicular non-Hodgkin lymphoma, unspecified                                                                                  1
# Other fall from one level to another                                                                                          1
# Psychological and behavioural factors associated with disorders or diseases classified elsewhere                              1
# Muscle wasting and atrophy, not elsewhere classified                                                                          1
# Amyloidosis, unspecified                                                                                                      1
# Surgical operation with implant of artificial internal device                                                                 1
# Obstructive and reflux uropathy, unspecified                                                                                  1
# Death from indirect obstetric cause occurring more than 42 days but less than one year after delivery                         1
# Haemorrhage, not elsewhere classified                                                                                         1
# Name: Cause of death, Length: 450, dtype: int64
# ---- Cause of death Code ---
# C34.9    835
# I25.1    811
# I21.9    787
# I25.0    696
# J44.9    639
# C18.9    617
# C25.9    602
# I64      602
# A41.9    584
# E14.9    560
# I11.9    555
# J18.9    543
# I50.0    530
# C80      511
# G30.9    483
# N18.5    481
# F03      473
# I10      455
# X42      448
# C50.9    441
# X44      423
# E14.2    407
# I42.9    402
# V89.2    396
# J69.0    375
# K74.6    359
# C71.9    357
# I61.9    349
# E11.9    344
# C90.0    344
#         ...
# W07        1
# B20.1      1
# C43.4      1
# I05.0      1
# J40        1
# E11.6      1
# V48.5      1
# I71.9      1
# I27.0      1
# D70        1
# I99        1
# C60.9      1
# O96.1      1
# I47.2      1
# C79.5      1
# R58        1
# R63.4      1
# G93.9      1
# A49.0      1
# V47.6      1
# N00.9      1
# A16.2      1
# D32.9      1
# K57.2      1
# F54        1
# Q89.7      1
# I20.9      1
# J10.1      1
# E87.1      1
# E85.9      1
# Name: Cause of death Code, Length: 450, dtype: int64
# ---- Crude Rate ---
# 1.1 (Unreliable)       222
# 2.9 (Unreliable)       214
# 1.5 (Unreliable)       212
# 1.3 (Unreliable)       205
# 2.1 (Unreliable)       195
# 0.9 (Unreliable)       195
# 2.6 (Unreliable)       186
# 1.2 (Unreliable)       186
# 1.0 (Unreliable)       186
# 1.6 (Unreliable)       183
# 1.9 (Unreliable)       166
# 3.1 (Unreliable)       159
# 5.0 (Unreliable)       159
# 1.7 (Unreliable)       156
# 1.8 (Unreliable)       155
# 4.5 (Unreliable)       151
# 3.6 (Unreliable)       151
# 3.3 (Unreliable)       150
# 1.4 (Unreliable)       149
# 2.3 (Unreliable)       149
# 3.5 (Unreliable)       149
# 2.7 (Unreliable)       147
# 4.8 (Unreliable)       147
# 3.0 (Unreliable)       145
# 2.8 (Unreliable)       144
# 2.4 (Unreliable)       143
# 2.2 (Unreliable)       134
# 3.8 (Unreliable)       133
# 3.4 (Unreliable)       131
# 3.9 (Unreliable)       130
#                       ...
# 193.4                    1
# 360.1                    1
# 203.8                    1
# 78.8 (Unreliable)        1
# 472.3 (Unreliable)       1
# 427.6 (Unreliable)       1
# 1421.2                   1
# 505.1                    1
# 767.1                    1
# 335.0                    1
# 925.0                    1
# 360.2                    1
# 508.6                    1
# 354.8                    1
# 377.4                    1
# 220.6                    1
# 289.4                    1
# 398.1                    1
# 1258.5 (Unreliable)      1
# 499.5                    1
# 428.1                    1
# 73.3 (Unreliable)        1
# 328.3 (Unreliable)       1
# 187.1                    1
# 108.8 (Unreliable)       1
# 108.5                    1
# 504.6                    1
# 295.4                    1
# 325.0                    1
# 216.6                    1
# Name: Crude Rate, Length: 4843, dtype: int64

# %% [markdown]
# **Findings**
# * The Notes column is blank
# * "Unreliable" is added text in Crude Rate (which explains why it's an object type)
# * There seem to be only 42 states
# * The 5-9 age group is not represented
# * The code columns won't be useful

# %% [markdown]
# The unneeded columns can be removed:

# %%
deaths = deaths[['State', 'Age Group', 'Gender', 'Race', 'Cause of death', 'Deaths', 'Population']]

# %% [markdown]
# Finally, those column names need updating to work better with code:

# %%
deaths.columns
# Out:
# Index(['State', 'Age Group', 'Gender', 'Race', 'Cause of death', 'Deaths',
#        'Population'],
#       dtype='object')

# %%
deaths.columns = ['state','age_group','gender','race','cause_of_death','deaths','population']

# %% [markdown]
# Seems appropriate to write to .csv before checking out some of the trends and findings.

# %%
deaths.to_csv('../data/deaths.csv', index = False)
